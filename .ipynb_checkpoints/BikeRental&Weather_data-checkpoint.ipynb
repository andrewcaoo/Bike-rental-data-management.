# %%
import pandas as pd
import glob

# %% [markdown]
# # I. Load the data

# %%
path = 'bike-rental-starter-kit/bike-rental-starter-kit/data/'
weather_data_df = pd.read_csv(path + 'newark_airport_2016.csv')
weather_data_df
# Out:
#          STATION                                         NAME        DATE  \
# 0    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-01
# 1    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-02
# 2    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-03
# 3    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-04
# 4    USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-05
# ..           ...                                          ...         ...
# 361  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-12-27
# 362  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-12-28
# 363  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-12-29
# 364  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-12-30
# 365  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-12-31
#
#       AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  TSUN  WDF2   WDF5  WSF2  \
# 0    12.75   NaN  0.00   0.0   0.0    41    43    34   NaN   270  280.0  25.9
# 1     9.40   NaN  0.00   0.0   0.0    36    42    30   NaN   260  260.0  21.0
# 2    10.29   NaN  0.00   0.0   0.0    37    47    28   NaN   270  250.0  23.9
# 3    17.22   NaN  0.00   0.0   0.0    32    35    14   NaN   330  330.0  25.9
# 4     9.84   NaN  0.00   0.0   0.0    19    31    10   NaN   360  350.0  25.1
# ..     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 361  13.65   NaN  0.01   0.0   0.0    53    62    40   NaN   270  270.0  29.1
# 362   8.28   NaN  0.00   0.0   0.0    41    43    31   NaN   330  330.0  19.9
# 363   8.05   NaN  0.36   0.0   0.0    38    45    31   NaN   170  150.0  18.1
# 364  14.99   NaN  0.00   0.0   0.0    37    42    32   NaN   270  270.0  25.9
# 365  12.30   NaN  0.00   0.0   0.0    35    44    29   NaN   200  220.0  21.9
#
#      WSF5
# 0    35.1
# 1    25.1
# 2    30.0
# 3    33.1
# 4    31.1
# ..    ...
# 361  38.0
# 362  25.1
# 363  25.1
# 364  33.1
# 365  28.0
#
# [366 rows x 16 columns]

# %%
files = glob.glob(path + "*citibike-tripdata.csv")

df_list = []
for f in (files):
    df = pd.read_csv(f)
    df_list.append(df)

citibikes_df = pd.concat(df_list)

citibikes_df.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %% [markdown]
# # II. Diagnose data

# %%
print(weather_data_df.columns)
print(weather_data_df.info())
print(weather_data_df.head(10))
print(len(weather_data_df))
print(weather_data_df[weather_data_df.duplicated()])
# weather_data_df.isna()
print(weather_data_df[weather_data_df['WSF5'].isna()])
print(weather_data_df[weather_data_df['WDF5'].isna()])
# .isna().sum()

missing_values = weather_data_df.isna().sum()
missing_proportion = missing_values / len(weather_data_df) * 100

# Comment:
    # The column name and data type is oke. 
    # PGTM and TSUN columns is all missing value. It need dop them. 
    # WSF5 and WDF5 columns have several missing value. It is MCAR. I think we need fill it by the median value. 
    # There is no duplicated observation here.
# Out:
# Index(['STATION', 'NAME', 'DATE', 'AWND', 'PGTM', 'PRCP', 'SNOW', 'SNWD',
#        'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF2', 'WDF5', 'WSF2', 'WSF5'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  366 non-null    object
#  1   NAME     366 non-null    object
#  2   DATE     366 non-null    object
#  3   AWND     366 non-null    float64
#  4   PGTM     0 non-null      float64
#  5   PRCP     366 non-null    float64
#  6   SNOW     366 non-null    float64
#  7   SNWD     366 non-null    float64
#  8   TAVG     366 non-null    int64
#  9   TMAX     366 non-null    int64
#  10  TMIN     366 non-null    int64
#  11  TSUN     0 non-null      float64
#  12  WDF2     366 non-null    int64
#  13  WDF5     364 non-null    float64
#  14  WSF2     366 non-null    float64
#  15  WSF5     364 non-null    float64
# dtypes: float64(9), int64(4), object(3)
# memory usage: 45.9+ KB
# None
#        STATION                                         NAME        DATE  \
# 0  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-01
# 1  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-02
# 2  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-03
# 3  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-04
# 4  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-05
# 5  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-06
# 6  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-07
# 7  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-08
# 8  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-09
# 9  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-01-10
#
#     AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  TSUN  WDF2   WDF5  WSF2  \
# 0  12.75   NaN  0.00   0.0   0.0    41    43    34   NaN   270  280.0  25.9
# 1   9.40   NaN  0.00   0.0   0.0    36    42    30   NaN   260  260.0  21.0
# 2  10.29   NaN  0.00   0.0   0.0    37    47    28   NaN   270  250.0  23.9
# 3  17.22   NaN  0.00   0.0   0.0    32    35    14   NaN   330  330.0  25.9
# 4   9.84   NaN  0.00   0.0   0.0    19    31    10   NaN   360  350.0  25.1
# 5   5.37   NaN  0.00   0.0   0.0    28    42    15   NaN   230  250.0  12.1
# 6   3.36   NaN  0.00   0.0   0.0    35    46    24   NaN    20  360.0   8.9
# 7   8.05   NaN  0.00   0.0   0.0    38    45    31   NaN    20   30.0  14.1
# 8   6.71   NaN  0.01   0.0   0.0    44    48    38   NaN    60   70.0  13.0
# 9  15.43   NaN  1.77   0.0   0.0    53    65    39   NaN   260  270.0  36.0
#
#    WSF5
# 0  35.1
# 1  25.1
# 2  30.0
# 3  33.1
# 4  31.1
# 5  16.1
# 6  10.1
# 7  16.1
# 8  17.0
# 9  42.9
# 366
# Empty DataFrame
# Columns: [STATION, NAME, DATE, AWND, PGTM, PRCP, SNOW, SNWD, TAVG, TMAX, TMIN, TSUN, WDF2, WDF5, WSF2, WSF5]
# Index: []
#          STATION                                         NAME        DATE  \
# 32   USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-02-02
# 329  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-11-25
#
#      AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  TSUN  WDF2  WDF5  WSF2  \
# 32    3.8   NaN  0.00   0.0   1.2    43    51    32   NaN   350   NaN  11.0
# 329   4.7   NaN  0.01   0.0   0.0    48    55    45   NaN   220   NaN   8.1
#
#      WSF5
# 32    NaN
# 329   NaN
#          STATION                                         NAME        DATE  \
# 32   USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-02-02
# 329  USW00014734  NEWARK LIBERTY INTERNATIONAL AIRPORT, NJ US  2016-11-25
#
#      AWND  PGTM  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN  TSUN  WDF2  WDF5  WSF2  \
# 32    3.8   NaN  0.00   0.0   1.2    43    51    32   NaN   350   NaN  11.0
# 329   4.7   NaN  0.01   0.0   0.0    48    55    45   NaN   220   NaN   8.1
#
#      WSF5
# 32    NaN
# 329   NaN

# %%
print(citibikes_df.columns)
print(citibikes_df.info())
print(citibikes_df.head(10))
print(len(citibikes_df))
# .isna().sum()

missing_values = citibikes_df.isna().sum()
missing_proportion = missing_values / len(citibikes_df) * 100
print(missing_proportion)

# Comment:
    # Column name is oke. 
    # The User Type and Birth Year columns have missing values. User type will fill by Customer value Birth year will fill by median value. 
    # The data type of the year column is not true. 
    # There is no duplicated observation here.
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247584 entries, 0 to 15113
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Trip Duration            247584 non-null  int64
#  1   Start Time               247584 non-null  object
#  2   Stop Time                247584 non-null  object
#  3   Start Station ID         247584 non-null  int64
#  4   Start Station Name       247584 non-null  object
#  5   Start Station Latitude   247584 non-null  float64
#  6   Start Station Longitude  247584 non-null  float64
#  7   End Station ID           247584 non-null  int64
#  8   End Station Name         247584 non-null  object
#  9   End Station Latitude     247584 non-null  float64
#  10  End Station Longitude    247584 non-null  float64
#  11  Bike ID                  247584 non-null  int64
#  12  User Type                247204 non-null  object
#  13  Birth Year               228585 non-null  float64
#  14  Gender                   247584 non-null  int64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 30.2+ MB
# None
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            362  2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1            200  2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2            202  2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3            248  2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4            903  2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# 5            883  2016-01-01 01:03:28  2016-01-01 01:18:11              3195
# 6            445  2016-01-01 01:07:45  2016-01-01 01:15:11              3186
# 7            192  2016-01-01 01:18:51  2016-01-01 01:22:03              3211
# 8            409  2016-01-01 01:23:44  2016-01-01 01:30:34              3187
# 9            285  2016-01-01 01:25:12  2016-01-01 01:29:57              3187
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1      Grove St PATH               40.719586               -74.043117
# 2      Grove St PATH               40.719586               -74.043117
# 3       Brunswick St               40.724176               -74.050656
# 4            Sip Ave               40.730743               -74.063784
# 5            Sip Ave               40.730743               -74.063784
# 6      Grove St PATH               40.719586               -74.043117
# 7         Newark Ave               40.721525               -74.046305
# 8          Warren St               40.721124               -74.038051
# 9          Warren St               40.721124               -74.038051
#
#    End Station ID  End Station Name  End Station Latitude  \
# 0            3209      Brunswick St             40.724176
# 1            3213    Van Vorst Park             40.718489
# 2            3213    Van Vorst Park             40.718489
# 3            3203     Hamilton Park             40.727596
# 4            3210    Pershing Field             40.742677
# 5            3210    Pershing Field             40.742677
# 6            3203     Hamilton Park             40.727596
# 7            3203     Hamilton Park             40.727596
# 8            3214  Essex Light Rail             40.712774
# 9            3214  Essex Light Rail             40.712774
#
#    End Station Longitude  Bike ID   User Type  Birth Year  Gender
# 0             -74.050656    24647  Subscriber      1964.0       2
# 1             -74.047727    24605  Subscriber      1962.0       1
# 2             -74.047727    24689  Subscriber      1962.0       2
# 3             -74.044247    24693  Subscriber      1984.0       1
# 4             -74.051789    24573    Customer         NaN       0
# 5             -74.051789    24442    Customer         NaN       0
# 6             -74.044247    24510  Subscriber      1988.0       2
# 7             -74.044247    24625  Subscriber      1980.0       1
# 8             -74.036486    24429  Subscriber      1990.0       1
# 9             -74.036486    24407  Subscriber      1988.0       2
# 247584
# Trip Duration              0.000000
# Start Time                 0.000000
# Stop Time                  0.000000
# Start Station ID           0.000000
# Start Station Name         0.000000
# Start Station Latitude     0.000000
# Start Station Longitude    0.000000
# End Station ID             0.000000
# End Station Name           0.000000
# End Station Latitude       0.000000
# End Station Longitude      0.000000
# Bike ID                    0.000000
# User Type                  0.153483
# Birth Year                 7.673759
# Gender                     0.000000
# dtype: float64

# %% [markdown]
# # III. Cleaning data.

# %%
# It not true. Because it assigned a new series of different length to the dataframe. 
# citibikes_df['Birth Year'] = citibikes_df[citibikes_df['Birth Year'].notna()]['Birth Year'].astype(int)
# citibikes_df['Birth Year'] = citibikes_df['Birth Year'].apply(lambda x: int(x) if not pd.isna(x) else x)

# Ensure 'Birth Year' column is of integer type with NA support
citibikes_df['Birth Year'] = citibikes_df['Birth Year'].astype('Int64')

# Fill NaN values
citibikes_df = citibikes_df.fillna(
    value={
        'User Type': 'Customer',
        'Birth Year': citibikes_df['Birth Year'].median()
    }
)

# Convert 'Start Time' and 'Stop Time' to datetime
citibikes_df['Start Time'] = pd.to_datetime(citibikes_df['Start Time'])
citibikes_df['Stop Time'] = pd.to_datetime(citibikes_df['Stop Time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 17
#       9 citibikes_df = citibikes_df.fillna(
#      10     value={
#      11         'User Type': 'Customer',
#      12         'Birth Year': citibikes_df['Birth Year'].median()
#      13     }
#      14 )
#      16 # Convert 'Start Time' and 'Stop Time' to datetime
# ---> 17 citibikes_df['Start Time'] = pd.to_datetime(citibikes_df['Start Time'])
#      18 citibikes_df['Stop Time'] = pd.to_datetime(citibikes_df['Stop Time'])
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\_libs\tslib.pyx:833, in pandas._libs.tslib._array_to_datetime_object()
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\_libs\tslib.pyx:655, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'datetime.time'> is not convertible to datetime

# %%
weather_data_df.drop(['TSUN','PGTM','STATION','NAME'], axis=1, inplace=True)

weather_data_df.fillna(
    value = {
        'WSF5': weather_data_df['WSF5'].median(),
        'WDF5': weather_data_df['WDF5'].median(),
    },
    inplace = True
) 

weather_data_df =  weather_data_df.astype({'DATE': 'datetime64[ns]'})

weather_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 weather_data_df.drop(['TSUN','PGTM','STATION','NAME'], axis=1, inplace=True)
#       3 weather_data_df.fillna(
#       4     value = {
#       5         'WSF5': weather_data_df['WSF5'].median(),
#    (...)
#       8     inplace = True
#       9 )
#      11 weather_data_df =  weather_data_df.astype({'DATE': 'datetime64[ns]'})
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['TSUN', 'PGTM', 'STATION', 'NAME'] not found in axis"

# %% [markdown]
# # IV.Data transform

# %%
# print(citibikes_df.head(10))
# start_t = citibikes_df['Start Time'].str.split(' ', expand=True)
# stop_t = citibikes_df['Stop Time'].str.split(' ', expand=True)

# assigned_data = {
#     'Start Date': start_t[0],
#     'Start Time': start_t[1],
#     'Stop Date':  stop_t[0],
#     'Stop Time' : stop_t[1],
# }

# citibikes_df.assign(**assigned_data)

# citibikes_df['Start Date'] = citibikes_df['Start Time'].dt.date
# citibikes_df['Stop Date'] = citibikes_df['Stop Time'].dt.date

# citibikes_df['Start Time'] = citibikes_df['Start Time'].dt.time
# citibikes_df['Stop Time'] = citibikes_df['Stop Time'].dt.time

pd.to_datetime(citibikes_df['Stop Date']).dt.year.value_counts()

# citibikes_df.head(5)
# Out:
# 2016    247584
# Name: Start Date, dtype: int64

# %% [markdown]
# # V.Create database

# %% [markdown]
# ## 1.Connection establishment

# %%
from sqlalchemy import create_engine, text
from dotenv import dotenv_values
from sqlalchemy.engine import URL

config = dotenv_values(".env") 

url_object = URL.create(
    config['POSTGRES_ASYNC_PREFIX'],
    username=config['POSTGRES_USER'],
    password=config['POSTGRES_PASSWORD'],
    host=config['POSTGRES_SERVER'],
    database=config['POSTGRES_DB']
)

engine = create_engine(url_object)
print(engine)
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/Bike_rental_data_management)

# %% [markdown]
# ## 2.Create the database

# %%
# Delete the existing table.

drop_tables = """
DROP TABLE IF EXISTS Fact_Trip;
DROP TABLE IF EXISTS Dim_Weather_Data;
DROP TABLE IF EXISTS Dim_Station;
DROP TABLE IF EXISTS Dim_Bike;
DROP TABLE IF EXISTS Dim_User;
"""


create_table = """
CREATE TABLE Dim_Station (
    Station_id SERIAL PRIMARY KEY,
    Station_name VARCHAR(255),
    Station_latitude FLOAT,
    Station_longitude FLOAT
);

CREATE TABLE Dim_Bike (
    Bike_id SERIAL PRIMARY KEY
);

CREATE TABLE Dim_User (
    User_id SERIAL PRIMARY KEY,
    User_Type VARCHAR(255),
    Birth_Year INTEGER,
    Gender VARCHAR(10)
);

CREATE TABLE Fact_Trip (
    Trip_id SERIAL PRIMARY KEY,
    Trip_duration INT,
    Start_date DATE,
    Stop_date DATE,
    Start_station INT,
    Stop_station INT,
    Bike_id INT,
    Start_time TIME,
    Stop_time TIME,
    User_id SERIAL
);

CREATE TABLE Dim_Weather_Data (
    Date DATE PRIMARY KEY,
    AWND FLOAT,
    PRCP FLOAT,
    SNOW FLOAT,
    SNWD FLOAT,
    TAVG FLOAT,
    TMAX FLOAT,
    TMIN FLOAT,
    WDF2 FLOAT,
    WDF5 FLOAT,
    WSF2 FLOAT,
    WSF5 FLOAT
);

alter table fact_trip
add constraint FK_fact_trip_to_dim_station foreign key (start_station) references dim_station(station_id);

alter table fact_trip
add constraint FK_fact_trip_stop_station_to_dim_station foreign key (stop_station) references dim_station(station_id);

alter table fact_trip
add constraint FK_fact_trip_bike_id_to_dim_bike foreign key (bike_id) references dim_bike(bike_id);

alter table fact_trip
add constraint FK_fact_trip_user_id_to_dim_user foreign key (user_id) references dim_user(user_id);

alter table fact_trip
add constraint FK_fact_trip_start_date_to_dim_start_date foreign key (start_date) references dim_weather_data(date);

alter table fact_trip
add constraint FK_fact_trip_stop_date_to_dim_stop_date foreign key (stop_date) references dim_weather_data(date);

"""

with engine.connect() as connection:
    connection.execute(text(drop_tables))
    connection.execute(text(create_table))

# %% [markdown]
# ## 3.Insert data from dataframe to the database

# %%
# Insert data into Dim_bike table

citibikes_df[citibikes_df['Birth Year'].isna()]

Bike_df =  pd.DataFrame(citibikes_df['Bike ID']).drop_duplicates()

Bike_df.columns = ['bike_id']

Bike_df.to_sql('dim_bike', engine, if_exists='append', index=False)

# Insert data into Dim_User table.

user_df = citibikes_df[['User Type','Birth Year', 'Gender']].drop_duplicates()
user_df['user_id'] = range(1, len(user_df) + 1)

user_df.rename(columns={
        'User Type': 'user_type',
        'Birth Year': 'birth_year',
        'Gender': 'gender'
            }, inplace=True)
user_df.columns
user_df.to_sql('dim_user', engine, if_exists='append', index=False)

# Insert data into Dim_bike table Dim_Station

start_station_df =  citibikes_df[['Start Station ID', 'Start Station Name', 'Start Station Latitude','Start Station Longitude']].drop_duplicates()
end_station_df =  citibikes_df[['End Station ID', 'End Station Name', 'End Station Latitude','End Station Longitude']].drop_duplicates()
end_station_df.rename(columns={
    'End Station ID': 'Start Station ID', 
    'End Station Name': 'Start Station Name',
    'End Station Latitude': 'Start Station Latitude',
    'End Station Longitude': 'Start Station Longitude'
}, inplace=True)

station_df = pd.concat([end_station_df, start_station_df]).drop_duplicates()

station_df.rename(columns={
    'Start Station ID': 'station_id',
    'Start Station Name': 'station_name',
    'Start Station Latitude': 'station_latitude',
    'Start Station Longitude': 'station_longitude'
}, inplace=True)

station_df.to_sql('dim_station', engine, if_exists='append', index=False)

# Insert data into Dim_bike table dim_weather_data 
weather_df = weather_data_df.drop_duplicates()

weather_df.rename(columns={
    'DATE': 'date',
    'AWND': 'awnd',
    'PRCP': 'prcp',
    'SNOW': 'snow',
    'SNWD': 'snwd',
    'TAVG': 'tavg',
    'TMAX': 'tmax',
    'TMIN': 'tmin',
    'WDF2': 'wdf2',
    'WDF5': 'wdf5',
    'WSF2': 'wsf2',
    'WSF5': 'wsf5'
}, inplace= True)
weather_df.to_sql('dim_weather_data', engine, if_exists='append', index=False)

# Insert data into Dim_bike table Fact_trip
trip_df = citibikes_df[['Trip Duration','Start Date', 'Stop Date', 'Start Time', 'Stop Time', 'Start Station ID', 'End Station ID', 'Bike ID', 'User Type', 'Birth Year', 'Gender']]
trip_df = trip_df.rename(columns={
    'Trip Duration': 'trip_duration',
    'Start Date': 'start_date',
    'Stop Date': 'stop_date',
    'Start Time': 'start_time',
    'Stop Time': 'stop_time',
    'Start Station ID': 'start_station',
    'End Station ID': 'stop_station',
    'Bike ID': 'bike_id'
    })

final_trip_df = pd.merge(
                    left = trip_df,
                    right = user_df,
                    left_on  = ['User Type', 'Birth Year', 'Gender'],
                    right_on = ['user_type','birth_year','gender'],
                    how = 'inner'
)
final_trip_df.drop(['User Type', 'Birth Year', 'Gender', 'user_type','birth_year','gender'], axis = 1, inplace=True)
final_trip_df['trip_id'] = range(1, len(final_trip_df) + 1)
final_trip_df.to_sql('fact_trip', engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:953, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     952     xtras = self._psycopg2_extras()
# --> 953     context._psycopg2_fetched_rows = xtras.execute_values(
#     954         cursor,
#     955         statement,
#     956         parameters,
#     957         template=executemany_values,
#     958         fetch=bool(context.compiled.returning),
#     959         **kwargs
#     960     )
#     962 elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\psycopg2\extras.py:1299, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298 parts[-1:] = post
# -> 1299 cur.execute(b''.join(parts))
#    1300 if fetch:
#
# ForeignKeyViolation: insert or update on table "fact_trip" violates foreign key constraint "fk_fact_trip_stop_date_to_dim_stop_date"
# DETAIL:  Key (stop_date)=(2017-01-01) is not present in table "dim_weather_data".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[12], line 87
#      85 final_trip_df.drop(['User Type', 'Birth Year', 'Gender', 'user_type','birth_year','gender'], axis = 1, inplace=True)
#      86 final_trip_df['trip_id'] = range(1, len(final_trip_df) + 1)
# ---> 87 final_trip_df.to_sql('fact_trip', engine, if_exists='append', index=False)
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:1738, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1726 sql_engine = get_engine(engine)
#    1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    (...)
#    1735     dtype=dtype,
#    1736 )
# -> 1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    1741     frame=frame,
#    1742     name=name,
#    1743     index=index,
#    1744     schema=schema,
#    1745     chunksize=chunksize,
#    1746     method=method,
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#    1751 return total_inserted
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:1335, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1333     raise ValueError("inf cannot be used with MySQL") from err
#    1334 else:
# -> 1335     raise err
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:1325, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1322 from sqlalchemy import exc
#    1324 try:
# -> 1325     return table.insert(chunksize=chunksize, method=method)
#    1326 except exc.SQLAlchemyError as err:
#    1327     # GH34431
#    1328     # https://stackoverflow.com/a/67358288/6067848
#    1329     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1330     )|inf can not be used with MySQL"""
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:946, in SQLTable.insert(self, chunksize, method)
#     943     break
#     945 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 946 num_inserted = exec_insert(conn, keys, chunk_iter)
#     947 # GH 46891
#     948 if is_integer(num_inserted):
#
# File C:\ProgramData\anaconda32\lib\site-packages\pandas\io\sql.py:853, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     841 """
#     842 Execute SQL statement inserting data
#     843
#    (...)
#     850    Each item contains a list of values to be inserted
#     851 """
#     852 data = [dict(zip(keys, row)) for row in data_iter]
# --> 853 result = conn.execute(self.table.insert(), data)
#     854 return result.rowcount
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\engine\base.py:1799, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                 break
#    1798     if not evt_handled:
# -> 1799         self.dialect.do_executemany(
#    1800             cursor, statement, parameters, context
#    1801         )
#    1802 elif not parameters and context.no_parameters:
#    1803     if self.dialect._has_events:
#
# File C:\ProgramData\anaconda32\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:953, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     951         kwargs = {}
#     952     xtras = self._psycopg2_extras()
# --> 953     context._psycopg2_fetched_rows = xtras.execute_values(
#     954         cursor,
#     955         statement,
#     956         parameters,
#     957         template=executemany_values,
#     958         fetch=bool(context.compiled.returning),
#     959         **kwargs
#     960     )
#     962 elif self.executemany_mode & EXECUTEMANY_BATCH:
#     963     if self.executemany_batch_page_size:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\psycopg2\extras.py:1299, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1297     parts.append(b',')
#    1298 parts[-1:] = post
# -> 1299 cur.execute(b''.join(parts))
#    1300 if fetch:
#    1301     result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "fact_trip" violates foreign key constraint "fk_fact_trip_stop_date_to_dim_stop_date"
# DETAIL:  Key (stop_date)=(2017-01-01) is not present in table "dim_weather_data".
#
# [SQL: INSERT INTO fact_trip (trip_duration, start_date, stop_date, start_time, stop_time, start_station, stop_station, bike_id, user_id, trip_id) VALUES (%(trip_duration)s, %(start_date)s, %(stop_date)s, %(start_time)s, %(stop_time)s, %(start_station)s, %(stop_station)s, %(bike_id)s, %(user_id)s, %(trip_id)s)]
# [parameters: ({'trip_duration': 362, 'start_date': datetime.date(2016, 1, 1), 'stop_date': datetime.date(2016, 1, 1), 'start_time': datetime.time(0, 2, 52), 'stop_time': datetime.time(0, 8, 54), 'start_station': 3186, 'stop_station': 3209, 'bike_id': 24647, 'user_id': 1, 'trip_id': 1}, {'trip_duration': 452, 'start_date': datetime.date(2016, 1, 3), 'stop_date': datetime.date(2016, 1, 3), 'start_time': datetime.time(16, 25, 48), 'stop_time': datetime.time(16, 33, 21), 'start_station': 3209, 'stop_station': 3185, 'bike_id': 24662, 'user_id': 1, 'trip_id': 2}, {'trip_duration': 227, 'start_date': datetime.date(2016, 1, 3), 'stop_date': datetime.date(2016, 1, 3), 'start_time': datetime.time(17, 11, 56), 'stop_time': datetime.time(17, 15, 43), 'start_station': 3211, 'stop_station': 3203, 'bike_id': 24633, 'user_id': 1, 'trip_id': 3}, {'trip_duration': 263, 'start_date': datetime.date(2016, 1, 3), 'stop_date': datetime.date(2016, 1, 3), 'start_time': datetime.time(18, 18, 14), 'stop_time': datetime.time(18, 22, 38), 'start_station': 3203, 'stop_station': 3211, 'bike_id': 24633, 'user_id': 1, 'trip_id': 4}, {'trip_duration': 497, 'start_date': datetime.date(2016, 1, 3), 'stop_date': datetime.date(2016, 1, 3), 'start_time': datetime.time(22, 11, 25), 'stop_time': datetime.time(22, 19, 43), 'start_station': 3186, 'stop_station': 3209, 'bike_id': 24597, 'user_id': 1, 'trip_id': 5}, {'trip_duration': 481, 'start_date': datetime.date(2016, 1, 4), 'stop_date': datetime.date(2016, 1, 4), 'start_time': datetime.time(19, 4, 6), 'stop_time': datetime.time(19, 12, 8), 'start_station': 3220, 'stop_station': 3210, 'bike_id': 24558, 'user_id': 1, 'trip_id': 6}, {'trip_duration': 327, 'start_date': datetime.date(2016, 1, 4), 'stop_date': datetime.date(2016, 1, 4), 'start_time': datetime.time(19, 11, 39), 'stop_time': datetime.time(19, 17, 7), 'start_station': 3211, 'stop_station': 3203, 'bike_id': 24559, 'user_id': 1, 'trip_id': 7}, {'trip_duration': 243, 'start_date': datetime.date(2016, 1, 4), 'stop_date': datetime.date(2016, 1, 4), 'start_time': datetime.time(20, 50, 36), 'stop_time': datetime.time(20, 54, 40), 'start_station': 3203, 'stop_station': 3211, 'bike_id': 24435, 'user_id': 1, 'trip_id': 8}  ... displaying 10 of 247584 total bound parameter sets ...  {'trip_duration': 990, 'start_date': datetime.date(2016, 12, 10), 'stop_date': datetime.date(2016, 12, 10), 'start_time': datetime.time(7, 16, 18), 'stop_time': datetime.time(7, 32, 48), 'start_station': 3269, 'stop_station': 3184, 'bike_id': 24569, 'user_id': 193, 'trip_id': 247583}, {'trip_duration': 122, 'start_date': datetime.date(2016, 12, 10), 'stop_date': datetime.date(2016, 12, 10), 'start_time': datetime.time(7, 36, 56), 'stop_time': datetime.time(7, 38, 58), 'start_station': 3184, 'stop_station': 3183, 'bike_id': 24569, 'user_id': 193, 'trip_id': 247584})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# # VI. Create the views.
